# %% [markdown]
# # How well do jobs & skills pay for Data Analytics ?

# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\91706\Data Analytics Practice\databases\python\Job_Data_Analysis.csv")

# %%
#Data Cleaning
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df1=df.dropna(subset='salary_year_avg')

# %%
job_titles=df1['job_title_short'].value_counts().index[:6].tolist()
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
df1_top6 = df1[df1['job_title_short'].isin(job_titles)]

# %%
job_order=df1_top6.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index

# %%
sns.boxplot(data=df1_top6,x='salary_year_avg',y='job_title_short',order=job_order)
sns.set_theme(style='ticks')

plt.title('Salary Distribution')
plt.xlabel('Yearly Salary USD')
plt.ylabel('')
plt.xlim(0,600000)
ticks_x=plt.FuncFormatter(lambda y,_: f'{int(y/1000)}K')
plt.gca().xaxis.set_major_formatter(ticks_x)
sns.despine()
plt.show()

# %% [markdown]
# # Investigate Median Salry VS Skill for Data Analyst

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
df_DA=df_DA.dropna(subset='salary_year_avg')

# %%
df_DA=df_DA.explode('job_skills')
df_DA.head(3)
# Out:
#     job_title_short                              job_title job_location  \
# 109    Data Analyst  Senior Supply Chain Analytics Analyst     Anywhere
# 109    Data Analyst  Senior Supply Chain Analytics Analyst     Anywhere
# 109    Data Analyst  Senior Supply Chain Analytics Analyst     Anywhere
#
#         job_via job_schedule_type  job_work_from_home  \
# 109  via Get.It         Full-time                True
# 109  via Get.It         Full-time                True
# 109  via Get.It         Full-time                True
#
#              search_location     job_posted_date  job_no_degree_mention  \
# 109  Illinois, United States 2023-10-12 13:02:19                  False
# 109  Illinois, United States 2023-10-12 13:02:19                  False
# 109  Illinois, United States 2023-10-12 13:02:19                  False
#
#      job_health_insurance    job_country salary_rate  salary_year_avg  \
# 109                  True  United States        year          89000.0
# 109                  True  United States        year          89000.0
# 109                  True  United States        year          89000.0
#
#      salary_hour_avg                     company_name job_skills  \
# 109              NaN  Get It Recruit - Transportation     python
# 109              NaN  Get It Recruit - Transportation          r
# 109              NaN  Get It Recruit - Transportation    alteryx
#
#                                        job_type_skills
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
df_DA_top_pay = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count','median']).sort_values(by='median',ascending=False)
df_DA_top_pay=df_DA_top_pay.head(10)
df_DA_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_DA_skills = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count','median']).sort_values(by='count',ascending=False)
df_DA_skills = df_DA_skills.head(10).sort_values(by='median',ascending=False)
df_DA_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig,ax= plt.subplots(2,1,figsize=(8,6))

sns.set_theme(style='ticks')

sns.barplot(data=df_DA_top_pay, x='median', y=df_DA_top_pay.index, hue='median', ax=ax[0], palette='dark:b_r')
ax[0].legend().remove()
ax[0].set_title('Top 10 Highest Paid Skills For Data Analayst')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_ : f'{int(x/1000)}K'))

sns.barplot(data=df_DA_skills,x='median',y=df_DA_skills.index,hue='median',ax=ax[1],palette='dark:b_r')
ax[1].legend().remove()
ax[1].set_title('Top 10 Most In demand Skills For Data Analayst')
ax[1].set_ylabel('')
ax[1].set_xlabel('')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_ : f'{int(x/1000)}K'))

plt.xlim(0,200000)

plt.tight_layout()
plt.show()
